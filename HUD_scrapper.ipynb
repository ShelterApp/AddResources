# %% [markdown]
# # Import Library

# %%
import pandas as pd

import warnings
warnings.simplefilter("ignore")

# %% [markdown]
# # Grab the data

# %%
# we will be using these columns
use_cols = ["Organization ID", "Organization Name", "Project Type", "address1", "address2", "city", "state", "zip"]

# %%
# read the data from HUD
df = pd.read_excel("https://www.huduser.gov/portal/sites/default/files/xls/2019-Housing-Inventory-County-RawFile.xlsx", usecols=use_cols)

# %%
df.head()
# Out:
#    Organization ID                Organization Name Project Type address1  \
# 0              495         Battered Women's Shelter           ES      NaN
# 1              495         Battered Women's Shelter           TH      NaN
# 2              495         Battered Women's Shelter          RRH      NaN
# 3            23705  Crisis Center of Russell County           ES      NaN
# 4             1943                         Daybreak           ES      NaN
#
#   address2 city state  zip
# 0      NaN  NaN   NaN  NaN
# 1      NaN  NaN   NaN  NaN
# 2      NaN  NaN   NaN  NaN
# 3      NaN  NaN   NaN  NaN
# 4      NaN  NaN   NaN  NaN

# %%
# all unique values for project type 
df["Project Type"].unique()
# Out:
# array(['ES', 'TH', 'RRH', 'PSH', 'OPH', 'SH'], dtype=object)

# %% [markdown]
# # Feature engineering

# %%
# one hot encode the "Project Type column"
df2 = pd.concat([df, pd.get_dummies(df["Project Type"])], axis = 1).drop("Project Type", axis = 1)

# %%
df2.head()
# Out:
#    Organization ID                Organization Name address1 address2 city  \
# 0              495         Battered Women's Shelter      NaN      NaN  NaN
# 1              495         Battered Women's Shelter      NaN      NaN  NaN
# 2              495         Battered Women's Shelter      NaN      NaN  NaN
# 3            23705  Crisis Center of Russell County      NaN      NaN  NaN
# 4             1943                         Daybreak      NaN      NaN  NaN
#
#   state  zip  ES  OPH  PSH  RRH  SH  TH
# 0   NaN  NaN   1    0    0    0   0   0
# 1   NaN  NaN   0    0    0    0   0   1
# 2   NaN  NaN   0    0    0    1   0   0
# 3   NaN  NaN   1    0    0    0   0   0
# 4   NaN  NaN   1    0    0    0   0   0

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25142 entries, 0 to 25141
# Data columns (total 13 columns):
# Organization ID      25142 non-null int64
# Organization Name    25142 non-null object
# address1             19920 non-null object
# address2             307 non-null object
# city                 20187 non-null object
# state                21179 non-null object
# zip                  23388 non-null float64
# ES                   25142 non-null uint8
# OPH                  25142 non-null uint8
# PSH                  25142 non-null uint8
# RRH                  25142 non-null uint8
# SH                   25142 non-null uint8
# TH                   25142 non-null uint8
# dtypes: float64(1), int64(1), object(5), uint8(6)
# memory usage: 1.5+ MB

# %%
# an example of an organization with multiple addresses
df2[df2["Organization ID"] == 7]
# Out:
#        Organization ID Organization Name           address1 address2  \
# 159                  7             ABCCM                NaN      NaN
# 15159                7             ABCCM  30 CUMBERLAND AVE      NaN
# 15160                7             ABCCM  30 CUMBERLAND AVE      NaN
# 15161                7             ABCCM     1329 TUNNEL RD      NaN
# 15162                7             ABCCM     1329 TUNNEL RD      NaN
# 15163                7             ABCCM     1329 TUNNEL RD      NaN
# 15164                7             ABCCM     1329 TUNNEL RD      NaN
# 15545                7             ABCCM     1329 TUNNEL RD      NaN
#
#             city state      zip  ES  OPH  PSH  RRH  SH  TH
# 159          NaN   NaN  28801.0   0    0    0    1   0   0
# 15159  Asheville    NC  28801.0   1    0    0    0   0   0
# 15160  ASHEVILLE    NC  28801.0   0    0    0    0   0   1
# 15161  ASHEVILLE    NC  28805.0   1    0    0    0   0   0
# 15162  ASHEVILLE    NC  28805.0   0    1    0    0   0   0
# 15163  ASHEVILLE    NC  28805.0   0    0    0    0   0   1
# 15164  ASHEVILLE    NC  28805.0   0    0    0    0   0   1
# 15545  Asheville    ND  28805.0   1    0    0    0   0   0

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ### Combine and Impute the address and city

# %%
# manipulate the string values
df2["city"] = df2["city"].str.title()
df2["address1"] = df2["address1"].str.upper()
df2["address2"] = df2["address2"].str.upper()
df2["zip"] = df2["zip"].fillna("missinggg").apply(lambda x: str(x)[:-2])

# %%
# changing nan values into an empty string
def change_nan(text):
    if str(text) == "nan":
        return ""
    else:
        return str(text)

# %%
# changing nan values in address2 column
df2["address2"] = df2["address2"].apply(lambda x: change_nan(x))

# %%
# combine the address
df2["address"] = df2["address1"] + df2["address2"]

# %%
df2 = df2.drop(["address1", "address2"], axis = 1)

# %%
df2.head()
# Out:
#        Organization ID                                  Organization Name  \
# 19685                1                                            12 & 12
# 19686                1                                            12 & 12
# 19687                1                                            12 & 12
# 5667                 3  24 Hour Oakland Parent / Teacher Children's Ce...
# 12704                6                                       Abby's House
#
#             city state    zip  ES  OPH  PSH  RRH  SH  TH  \
# 19685      Tulsa    OK  74119   0    0    0    0   0   1
# 19686      Tulsa    OK  74135   0    0    0    0   0   1
# 19687      Tulsa    OK  74135   0    0    0    0   0   1
# 5667     Oakland    CA  94601   1    0    0    0   0   0
# 12704  Worcester    MA   1609   1    0    0    0   0   0
#
#                        address
# 19685   1214 S. BALTIMORE AVE.
# 19686         6333 E SKELLY DR
# 19687         6333 E SKELLY DR
# 5667   4700 INTERNATIONAL BLVD
# 12704              23 CROWN ST

# %%
# impute address
df2 = df2.sort_values(["Organization ID", "Organization Name", "zip", "address"]).reset_index(drop = True)
for i in range(1, df2.shape[0]):
    
    # if we found missing value on column address1
    if df2["address"][i] != df2["address"][i]:
        
        if df2["Organization ID"][i] == df2["Organization ID"][i-1] and df2["zip"][i] == df2["zip"][i-1]:
            
            df2["address"][i] = df2["address"][i-1]
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
# impute city
df2 = df2.sort_values(["Organization ID", "Organization Name", "zip", "city"]).reset_index(drop = True)
for i in range(1, df2.shape[0]):
    
    # if we found missing value on column city
    if df2["city"][i] != df2["city"][i]:
        
        if df2["Organization ID"][i] == df2["Organization ID"][i-1] and df2["zip"][i] == df2["zip"][i-1]:
            
            df2["city"][i] = df2["city"][i-1]
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df2[df2["Organization ID"] == 7]
# Out:
#     Organization ID Organization Name       city state    zip  ES  OPH  PSH  \
# 5                 7             ABCCM  Asheville    NC  28801   1    0    0
# 6                 7             ABCCM  Asheville    NC  28801   0    0    0
# 7                 7             ABCCM  Asheville   NaN  28801   0    0    0
# 8                 7             ABCCM  Asheville    NC  28805   1    0    0
# 9                 7             ABCCM  Asheville    NC  28805   0    1    0
# 10                7             ABCCM  Asheville    NC  28805   0    0    0
# 11                7             ABCCM  Asheville    NC  28805   0    0    0
# 12                7             ABCCM  Asheville    ND  28805   1    0    0
#
#     RRH  SH  TH            address
# 5     0   0   0  30 CUMBERLAND AVE
# 6     0   0   1  30 CUMBERLAND AVE
# 7     1   0   0  30 CUMBERLAND AVE
# 8     0   0   0     1329 TUNNEL RD
# 9     0   0   0     1329 TUNNEL RD
# 10    0   0   1     1329 TUNNEL RD
# 11    0   0   1     1329 TUNNEL RD
# 12    0   0   0     1329 TUNNEL RD

# %% [markdown]
# ### Drop duplicates

# %%
df3 = df2

# %%
col = ["Organization ID", "Organization Name", "address", "city", "state", "zip", "ES", "OPH", "PSH", "RRH", "SH", "TH"]
df3 = df3.drop_duplicates(col)

# %%
df3[df3["Organization ID"] == 7]
# Out:
#     Organization ID Organization Name       city state    zip  ES  OPH  PSH  \
# 5                 7             ABCCM  Asheville    NC  28801   1    0    0
# 6                 7             ABCCM  Asheville    NC  28801   0    0    0
# 7                 7             ABCCM  Asheville   NaN  28801   0    0    0
# 8                 7             ABCCM  Asheville    NC  28805   1    0    0
# 9                 7             ABCCM  Asheville    NC  28805   0    1    0
# 10                7             ABCCM  Asheville    NC  28805   0    0    0
# 12                7             ABCCM  Asheville    ND  28805   1    0    0
#
#     RRH  SH  TH            address
# 5     0   0   0  30 CUMBERLAND AVE
# 6     0   0   1  30 CUMBERLAND AVE
# 7     1   0   0  30 CUMBERLAND AVE
# 8     0   0   0     1329 TUNNEL RD
# 9     0   0   0     1329 TUNNEL RD
# 10    0   0   1     1329 TUNNEL RD
# 12    0   0   0     1329 TUNNEL RD

# %%
col_nostate = ["Organization ID", "Organization Name", "address", "city", "zip", "ES", "OPH", "PSH", "RRH", "SH", "TH"]
df3 = df3.drop_duplicates(col_nostate)

# %%
df3[df3["Organization ID"] == 7]
# Out:
#     Organization ID Organization Name       city state    zip  ES  OPH  PSH  \
# 5                 7             ABCCM  Asheville    NC  28801   1    0    0
# 6                 7             ABCCM  Asheville    NC  28801   0    0    0
# 7                 7             ABCCM  Asheville   NaN  28801   0    0    0
# 8                 7             ABCCM  Asheville    NC  28805   1    0    0
# 9                 7             ABCCM  Asheville    NC  28805   0    1    0
# 10                7             ABCCM  Asheville    NC  28805   0    0    0
#
#     RRH  SH  TH            address
# 5     0   0   0  30 CUMBERLAND AVE
# 6     0   0   1  30 CUMBERLAND AVE
# 7     1   0   0  30 CUMBERLAND AVE
# 8     0   0   0     1329 TUNNEL RD
# 9     0   0   0     1329 TUNNEL RD
# 10    0   0   1     1329 TUNNEL RD

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20394 entries, 0 to 25141
# Data columns (total 12 columns):
# Organization ID      20394 non-null int64
# Organization Name    20394 non-null object
# city                 17097 non-null object
# state                17229 non-null object
# zip                  20394 non-null object
# ES                   20394 non-null uint8
# OPH                  20394 non-null uint8
# PSH                  20394 non-null uint8
# RRH                  20394 non-null uint8
# SH                   20394 non-null uint8
# TH                   20394 non-null uint8
# address              16861 non-null object
# dtypes: int64(1), object(5), uint8(6)
# memory usage: 1.2+ MB

# %%
'''
Emergency Shelter (ES)
Transitional Housing (TH)
Safe Haven (SH)
Permanent Supportive Housing (PSH)
Rapid Re-housing (RRH)
Other Permanent Housing (OPH)
'''
# Out:
# '\nEmergency Shelter (ES)\nTransitional Housing (TH)\nSafe Haven (SH)\nPermanent Supportive Housing (PSH)\nRapid Re-housing (RRH)\nOther Permanent Housing (OPH)\n'

# %% [markdown]
# ### Impute the rest of the columns (city, state, address)

# %%
df3 = df3.drop(["city", "state"], axis = 1)

# %%
df3.columns = ['Organization ID', 'Organization Name', 'Zip Code', 'ES', 'OPH', 'PSH',
       'RRH', 'SH', 'TH', 'address']

# %%
df3.set_index("Zip Code")
# Out:
#           Organization ID                                  Organization Name  \
# Zip Code
# 74119                   1                                            12 & 12
# 74135                   1                                            12 & 12
# 94601                   3  24 Hour Oakland Parent / Teacher Children's Ce...
# 1609                    6                                       Abby's House
# 28801                   7                                              ABCCM
# 28801                   7                                              ABCCM
# 28801                   7                                              ABCCM
# 28805                   7                                              ABCCM
# 28805                   7                                              ABCCM
# 28805                   7                                              ABCCM
# 99501                  10               Abused Women's Aid in Crisis (AWAIC)
# 99501                  10               Abused Women's Aid in Crisis (AWAIC)
# 99504                  10               Abused Women's Aid in Crisis (AWAIC)
# 20032                  12                                     Access Housing
# 20032                  12                                     Access Housing
# 20032                  12                                     Access Housing
# 80022                  13                                     ACCESS Housing
# 14804                  14                                       ACCORD Corp.
# 14813                  14                                       ACCORD Corp.
# 95603                  16                                      Acres of Hope
# missing                17                                                ACT
# 20136                  19         Action in Community Through Service (ACTS)
# 22026                  19         Action in Community Through Service (ACTS)
# 22026                  19         Action in Community Through Service (ACTS)
# 22026                  19         Action in Community Through Service (ACTS)
# missing                19         Action in Community Through Service (ACTS)
# 19121                  20               ACTS Christian Transitional Services
# 19121                  20               ACTS Christian Transitional Services
# 12801                  22                              Adirondack Vets House
# 12801                  22                              Adirondack Vets House
# ...                   ...                                                ...
# 76306               43420                                     Evangel Church
# 66104               43421                                     Bridge of Hope
# 37203               43422                                         Launch Pad
# 98221               43423                         Salvation Army (Anacortes)
# 98663               43424                               LIfeline Connections
# 19977               43425                 Centennial United Methodist Church
# 19904               43426                       Hopes and Dreams Code Purple
# 98661               43428                       Salvation Army-Vancouver, WA
# 8060                43432                 No Greater Love Community Services
# 96097               43444               Beacon of Hope Gospel Rescue Mission
# missing             43445                         Shasta Women's Refuge, Inc
# missing             43445                         Shasta Women's Refuge, Inc
# 95961               43446         Environmental Alternatives Family Services
# 95971               43446         Environmental Alternatives Family Services
# 96118               43447            Sierra County Health and Human Services
# 95971               43448                    Plumas County Behavioral Health
# missing             43449                      Women in Safe Homes Ketchikan
# 99835               43450                           Youth Advocates of Sitka
# 2904                43451  Holy Family Home for Women and Children (Non-P...
# 32796               43452                    Disabled Amer. Vet. Chapter 109
# 89503               43453                              Northern Nevada HOPES
# 80205               43454                                               MDHI
# 95531               43455                               Rural Human Services
# 95531               43456         Del Norte County Health and Human Services
# 95531               43456         Del Norte County Health and Human Services
# 32401               43460                                               FEMA
# 8619                43461                                         Soldier On
# 8332                43462     The Veterans Multi-Service Center - Burlington
# 95482               43463                Federal Emergency Management Agency
# 95667               43465                 El Dorado Public Housing Authority
#
#           ES  OPH  PSH  RRH  SH  TH                             address
# Zip Code
# 74119      0    0    0    0   0   1              1214 S. BALTIMORE AVE.
# 74135      0    0    0    0   0   1                    6333 E SKELLY DR
# 94601      1    0    0    0   0   0             4700 INTERNATIONAL BLVD
# 1609       1    0    0    0   0   0                         23 CROWN ST
# 28801      1    0    0    0   0   0                   30 CUMBERLAND AVE
# 28801      0    0    0    0   0   1                   30 CUMBERLAND AVE
# 28801      0    0    0    1   0   0                   30 CUMBERLAND AVE
# 28805      1    0    0    0   0   0                      1329 TUNNEL RD
# 28805      0    1    0    0   0   0                      1329 TUNNEL RD
# 28805      0    0    0    0   0   1                      1329 TUNNEL RD
# 99501      1    0    0    0   0   0                                 NaN
# 99501      0    0    0    0   0   1                                 NaN
# 99504      0    0    0    0   0   1                                 NaN
# 20032      0    0    1    0   0   0                820 CHESAPEAKE ST SE
# 20032      0    0    0    0   0   1           842 CHESAPEAKE STREET, SE
# 20032      0    0    1    0   0   0           842 CHESAPEAKE STREET, SE
# 80022      1    0    0    0   0   0                  6978 COLORADO BLVD
# 14804      0    0    0    0   0   1                          70 MAIN ST
# 14813      0    0    0    1   0   0                      84 SCHUYLER ST
# 95603      0    0    0    0   0   1                     13675 BOWMAN RD
# missing    1    0    0    0   0   0                                 NaN
# 20136      0    0    0    1   0   0                                 NaN
# 22026      0    0    0    1   0   0                      17866 MAIN ST.
# 22026      1    0    0    0   0   0                   17866 MAIN STREET
# 22026      0    0    0    1   0   0                   17866 MAIN STREET
# missing    1    0    0    0   0   0                                 NaN
# 19121      1    0    0    0   0   0                 1428 N. 28TH STREET
# 19121      1    0    0    0   0   0               1429 N NEWKIRK STREET
# 12801      0    0    1    0   0   0                          26 PINE ST
# 12801      0    0    0    0   0   1                          26 PINE ST
# ...       ..  ...  ...  ...  ..  ..                                 ...
# 76306      0    0    0    0   0   1                     1812 MAURINE ST
# 66104      1    0    0    0   0   0                     1925 N 11TH ST.
# 37203      1    0    0    0   0   0                     P.O. BOX 330695
# 98221      1    0    0    0   0   0                     3001 R AVE #100
# 98663      0    0    0    1   0   0  1601 FOURTH PLAIN BLVD., 2ND FLOOR
# 19977      1    0    0    0   0   0                   44 E MT VERNON ST
# 19904      1    0    0    0   0   0                   621 W DIVISION ST
# 98661      0    0    0    1   0   0                 7509 NE 47TH AVENUE
# 8060       1    0    0    0   0   0                       415 KEIM BLVD
# 96097      1    0    0    0   0   0                          PO BOX 557
# missing    1    0    0    0   0   0                                 NaN
# missing    0    0    0    0   0   1                                 NaN
# 95961      0    0    0    0   0   1               2015 AND 2017 PINE ST
# 95971      0    0    0    0   0   1                    68 MILL CREEK RD
# 96118      1    0    0    0   0   0                         711 MAIN ST
# 95971      0    0    0    0   0   1                                 NaN
# missing    1    0    0    0   0   0                                 NaN
# 99835      0    0    0    0   0   1                  805 LINCOLN STREET
# 2904       1    0    0    0   0   0                      979 BRANCH AVE
# 32796      1    0    0    0   0   0                435 N SINGLETON AVE.
# 89503      0    0    0    0   0   1                                 NaN
# 80205      1    0    0    0   0   0                   711 PARK AVE WEST
# 95531      1    0    0    0   0   0                           286 M ST.
# 95531      0    0    0    0   0   1                                 NaN
# 95531      0    0    1    0   0   0                                 NaN
# 32401      1    0    0    0   0   0                                 NaN
# 8619       0    0    0    1   0   0                                 NaN
# 8332       0    0    0    1   0   0                                 NaN
# 95482      0    0    0    0   0   1                                 NaN
# 95667      0    0    1    0   0   0                                 NaN
#
# [20394 rows x 9 columns]

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20394 entries, 0 to 25141
# Data columns (total 10 columns):
# Organization ID      20394 non-null int64
# Organization Name    20394 non-null object
# Zip Code             20394 non-null object
# ES                   20394 non-null uint8
# OPH                  20394 non-null uint8
# PSH                  20394 non-null uint8
# RRH                  20394 non-null uint8
# SH                   20394 non-null uint8
# TH                   20394 non-null uint8
# address              16861 non-null object
# dtypes: int64(1), object(3), uint8(6)
# memory usage: 916.1+ KB

# %%
df_zip = pd.read_csv("USZipCodes202003.csv")

# %%
df_zip["Zip Code"] = df_zip["Zip Code"].apply(lambda x: str(x))

# %%
df4 = df3.join(df_zip, how = "left", on = "Zip Code")[["Organization ID", "Organization Name", "City", "State", "Zip Code", "ES",
                                                                          "OPH", "PSH", "RRH", "SH", "TH"]]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-262-a0cc88c74608> in <module>
# ----> 1 df4 = df3.join(df_zip, how = "left", on = "Zip Code")[["Organization ID", "Organization Name", "City", "State", "Zip Code", "ES",
#       2                                                                           "OPH", "PSH", "RRH", "SH", "TH"]]
#
# C:\Anaconda\lib\site-packages\pandas\core\frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    6813         # For SparseDataFrame's benefit
#    6814         return self._join_compat(other, on=on, how=how, lsuffix=lsuffix,
# -> 6815                                  rsuffix=rsuffix, sort=sort)
#    6816
#    6817     def _join_compat(self, other, on=None, how='left', lsuffix='', rsuffix='',
#
# C:\Anaconda\lib\site-packages\pandas\core\frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    6828             return merge(self, other, left_on=on, how=how,
#    6829                          left_index=on is None, right_index=True,
# -> 6830                          suffixes=(lsuffix, rsuffix), sort=sort)
#    6831         else:
#    6832             if on is not None:
#
# C:\Anaconda\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      45                          right_index=right_index, sort=sort, suffixes=suffixes,
#      46                          copy=copy, indicator=indicator,
# ---> 47                          validate=validate)
#      48     return op.get_result()
#      49
#
# C:\Anaconda\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     531         # validate the merge keys dtypes. We may need to coerce
#     532         # to avoid incompat dtypes
# --> 533         self._maybe_coerce_merge_keys()
#     534
#     535         # If argument passed to validate,
#
# C:\Anaconda\lib\site-packages\pandas\core\reshape\merge.py in _maybe_coerce_merge_keys(self)
#     978                       (inferred_right in string_types and
#     979                        inferred_left not in string_types)):
# --> 980                     raise ValueError(msg)
#     981
#     982             # datetimelikes must match exactly
#
# ValueError: You are trying to merge on object and int64 columns. If you wish to proceed you should use pd.concat

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34595 entries, 0 to 34594
# Data columns (total 11 columns):
# Organization ID      34595 non-null int64
# Organization Name    34595 non-null object
# City                 33049 non-null object
# State                33049 non-null object
# Zip Code             33049 non-null object
# ES                   34595 non-null uint8
# OPH                  34595 non-null uint8
# PSH                  34595 non-null uint8
# RRH                  34595 non-null uint8
# SH                   34595 non-null uint8
# TH                   34595 non-null uint8
# dtypes: int64(1), object(4), uint8(6)
# memory usage: 1.8+ MB
